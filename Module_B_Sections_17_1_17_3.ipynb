# %% [markdown]
# <a href="https://colab.research.google.com/github/ggonz105/MAT-421/blob/main/Module_B_Sections_17_1_17_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Section 17.1 Interpolation Problem Statement**

# %% [markdown]
# Assume there is a data set with independent values of x and y, and there is a desired value that lies within those data sets but is not explicitly defined. This value can then be estimated through interpolation of the data sets.

# %% [markdown]
# **Section 17.2 Linear Interpolation**

# %% [markdown]
# Linear interpolation is the simplest form of interpolating data. When using linear interpolation, it is assumed that the point to be found lies on the line joining the nearest points to the left and right.
#
# This results in the following generalized linear interpolation equation:
# y(x)=yi+(yi+1−yi)(x−xi)/(xi+1−xi), where  xi  is the nearest point less than x and xi+1 is the nearest point greater than x, and (yi+1−yi)/(xi+1−xi) is the slope and yi is the y value that corresponds to the x value of xi.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [4, 5, 6]
y = [3, 10, 7]

x_interp = 5.3
y_interp = round(np.interp(x_interp, x, y),1)
print(y_interp)
# Out:
# 9.1

# %%
plt.figure(figsize = (10,8))
plt.plot(x, y, '-ob')
plt.plot(5.3, y_interp, 'ro')
plt.title('Linear Interpolation at x = 5.3')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Section 17.3 Cubic Spline Interpolation**

# %% [markdown]
# Cubic spline interpolation allows for a smoother approximation for non-linear data sets like the example set used by assuming:
#
# From [Python Numerical Methods](https://pythonnumericalmethods.berkeley.edu/notebooks/chapter17.03-Cubic-Spline-Interpolation.html)
#
# > that the points $(x_i,y_i)$ and $(x_{i+1},y_{i+1})$ are joined by a cubic polynomial $S_i(x)=a_ix^3+b_ix^2+c_ix+d_i$ that is valid for $x_i≤x≤x_{i+1}$ for i=1,…,n−1
#
# For n points, there will be n-1 cubic functions to find, with each function requiring 4 coefficients

# %%
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

x = [4, 5, 6]
y = [3, 10, 7]

f = CubicSpline(x, y, bc_type='natural')
x_new = np.linspace(4, 6, 100)
y_new = f(x_new)

plt.figure(figsize = (10,8))
plt.plot(x_new, y_new, 'b')
plt.plot(x, y, 'ro')
plt.title('Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
